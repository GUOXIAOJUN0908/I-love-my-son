# %% [markdown]
# CET1021 Data Structures and Algorithms with Python

# %% [markdown]
# # Graph (Part 2)
# ## Exercise
# ---

# %% [markdown]
# ### Question 1
#
# Using pen and paper, construct the minimum spanning tree (MST) of the graphs below using **Prim's algorithm**, staring from vertex **S**.
#
# Use Python codes to verify your MST.

# %% [markdown]
# **(i)**:
# ![prim_2.svg](attachment:prim_2.svg)

# %% [markdown]
# **(ii)**:
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### Question 2
#
# Using pen and paper, construct the minimum spanning tree of the graphs above using **Kruskal's algorithm**.
#
# Use Python codes to verify your MST.

# %% [markdown]
# ---
